# %% [markdown]
# #### Experiment 1

# %% [markdown]
# This notebook contains the code for experiment 1.

# %% [markdown]
# ## Loading libraries/packages and the training and test data

# %%
import ssl
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

import numpy as np
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
ssl._create_default_https_context = ssl._create_unverified_context
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag import pos_tag
from itertools import chain

import nltk
import sklearn 
import scipy.stats
import spacy_dbpedia_spotlight

# %%
# %store -r test_data

# %%
train_sents = list(nltk.corpus.conll2002.iob_sents('ned.train'))

# %% [markdown]
# ## Feature engineering (credits: https://github.com/TeamHG-Memex/sklearn-crfsuite/blob/master/docs/CoNLL2002.ipynb)

# %%
def word2features(sent, i):
    token = sent[i][0]
    features = {
        'word': token
    }
    if i > 0:
        prev = sent[i-1][0]
        features.update({
            '-1:word': prev
        })
    
    if i > 1:
        prev = sent[i-2][0]
        features.update({
            '-2:word': prev
    })
        
    if i < len(sent)-1:
        next_token = sent[i+1][0]
        features.update({
            '+1:word': next_token
        })
        
    if i < len(sent)-2:
        next_token = sent[i+2][0]
        features.update({
            '+2:word': next_token,
            
        })

                
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %% [markdown]
# ### Training

# %%
training_features = [sent2features(s) for s in train_sents]
training_labels = [sent2labels(s) for s in train_sents]

# %%
import sklearn_crfsuite
from sklearn_crfsuite import CRF
from sklearn.metrics import classification_report

crf = CRF(algorithm='l2sgd',
          max_iterations=100,
          all_possible_transitions=False)

# %%
crf.fit(training_features, training_labels)
# Out:
# CRF(algorithm='l2sgd', all_possible_transitions=False, max_iterations=100)

# %% [markdown]
# ### Feature extraction for test data

# %%
test_inputs = []
for snippet in test_data:
    sent_features = [sent2features(s) for s in snippet]
    test_inputs.append(sent_features)

# %% [markdown]
# ## Model predictions

# %%
from sklearn.metrics import classification_report
pred_outputs = []
for biography in test_inputs:
    pred = crf.predict(biography)
    pred_outputs.append(pred)

# %% [markdown]
# ## Formatting predictions

# %%
list_of_pred = [] 
for snippet in pred_outputs:
    for sent in snippet:
        for token in sent:
            list_of_pred.append(token)

# %%
pred_test_set = test_data
for snippet_index in range(len(pred_test_set)):
    snippet = pred_test_set[snippet_index]
    for sent_index in range(len(snippet)):
        sent = snippet[sent_index]
        pred_test_set[snippet_index][sent_index]= [list(ele) for ele in sent]

# %%
k = 0 
i = 0
for snippet_i in range(len(pred_test_set)):
    snippet = pred_test_set[snippet_i]
    for sent_i in range(len(snippet)):
        sent= pred_test_set[snippet_i][sent_i]
        for token_i in range(len(sent)):
            pred_ner = list_of_pred[k]
            pred_test_set[snippet_i][sent_i][token_i].append(pred_ner)
            k+=1
            i += 1

# %% [markdown]
# ## Visualizing predicted results

# %%
def visualize_biography(text):
    import spacy
    from spacy.tokens import Doc, Span
    from spacy import displacy

    nlp = spacy.load("en_core_web_sm")

    vocab = nlp.vocab
    colors = {"B-PER": "#ADD8E6","I-PER": "#ADD8E6", "B-LOC": "#FFD580", "I-LOC": "#FFD580", "B-ORG":"#90EE90","I-ORG":"#90EE90", "B-MISC":"#D8BFD8","I-MISC":"#D8BFD8"}



    docs = []
  
    for sentence in text:
        without_pos = [[a, c] for [a, b, c] in sentence]
        words, entities = zip(*without_pos)
        doc = Doc(vocab, words=words)
        spans = [Span(doc, i, i + 1, label=ent_type) for i, ent_type in enumerate(entities) if ent_type]
        doc.ents = spans
        docs.append(doc)

    options = {"ents": ["B-PER", "I-PER","B-ORG","I-ORG", "B-LOC","I-LOC","B-MISC","I-MISC"], "colors": colors}
    displacy.render(docs, style="ent", options=options, jupyter=True)

# %%
def count_tag(tag,test_set): 
    count = 0 
    for bio in test_set:
        for sentence in bio: 
            for token in sentence:
                if token[2] == tag:
                    count += 1
                    
    return count

# %%
print('B-PER', count_tag('B-PER',pred_test_set))
print('I-PER',count_tag('I-PER',pred_test_set))
print('B-LOC',count_tag('B-LOC',pred_test_set))
print('I-LOC',count_tag('I-LOC',pred_test_set))
print('B-ORG',count_tag('B-ORG',pred_test_set))
print('I-ORG',count_tag('I-ORG',pred_test_set))
print('B-MISC',count_tag('B-MISC',pred_test_set))
print('I-MISC',count_tag('I-MISC',pred_test_set))
# Out:
# B-PER 347
# I-PER 316
# B-LOC 261
# I-LOC 17
# B-ORG 10
# I-ORG 12
# B-MISC 55
# I-MISC 50

# %%
i=0
for bio in pred_test_set:
    print("Bio: ",i)
    visualize_biography(bio)
    i+=1
# Out:
# Bio:  0
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MATHAM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Theodorus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ) , zoon van Jacobus Matham , werd in 1598 te Haarlem geboren , bezocht Italië , en arbeidde aldaar met Cornelis Blommaent , Natalis Persyn en andere Vlaamsche schilders aan de Standbeelden enz. in de galerij van het paleis Ginstiniani . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij vestigde zich vervolgens te 's Hage , waar hij een der medeoprigters van de kamer Pictura was . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij sneed vele voortreffelijke portretten naar de beroemde meesters , die door Nagler en Kramm worden vermeld . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zoo als dat van Michiel le Blon , agent van de koningin en de kroon van Zweden bij Z.M. den koning van Groot-Brittanje in fol . ; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">naar van Dyck ; Philip Rovenius , pauselijk vicaris in
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     België
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , naar
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rubens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , in
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Stephan Crachtius Campensis , naar Spilberge , fol . ; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Reinier Pauw , Eques auratus Amstelodami naar J. Mytens of J v.
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ravesteyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Theod . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Graswinkelius , naar J.v . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Miereveld , in fol . ; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Johannes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Visscher
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , in fol . ; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Cornelius Simonis Kluverius , naar F. de Grebber , in fol . ; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Joost van Vondel , naar Sandrart ; Vopiscus Fortunatus Plempius , Med. Dr. naar Backer ; D. Gerardus Vossius , Canonicus Cantuariensis , naar Sandrart ; Caspar Barlaeus Med dr. naar
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     denzelfden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joannes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Banning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Wuytiers </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">op zijn sterfbed . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">fol . ; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Gerardus van Hoogeveen 4o . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ovaal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Pater van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     der
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scruys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , in fol . ; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Victus Jacobus
# <mark class
# Bio:  1
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Adel , aquarellist , schilder . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Geboren : 30 maart 1880 , Venlo . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Gestorven : 4 februari 1951 , Den Haag . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Plaats en periode van werkzaamheid : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Den Haag , van 1895 tot 1951 Ca. van vóór 1895-1951 . </div></span>
# Bio:  2
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HOUTEN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  ( Mr. Bernardus Albertus . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">van ) , studeerde te Leyden , werd 5 Oct . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1793 mr. in de regten . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">na het verdedigen eener
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diss.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jur.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">de
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Judicibus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hollandis </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     certa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     privatas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">judicandi </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">causas </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">norma nusquam distitutis cet . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij vestigde zich te Amsterdam en
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     stierf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij schreef : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Verhandeling over
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pligt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  der regters in Holland en West-Vriesland om alleen naar den inhoud der wetten vonnis te vellen , Amst . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-MISC</span>
# </mark>
#
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-MISC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">VII , bl.
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     362-375
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Boekzaal der Geleerde Wereld , 1769 , bl. 28-41 . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Voordracht van F. Buitenrust Hettema voor het Utr . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Genootschap , IV ; Rotterd . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Courant , 16 Febr . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1920 . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Mijn opstel in It Heitelan ( Snits 1919 ) bl. 43 . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Wumkes </div></span>
# Bio:  10
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CABELJAU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  (
# ...
#     1838-1865
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  ( emer . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">om ge-
#  zondheidsredenen ) . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij huwde 14 apr . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1830
#  met jkvw . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Philippine
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rijnhardia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HenriÃ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">« tte van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lijnden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1805-1865
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ) .
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">H. promoveerde bij H. Bouman met een La- </div></span>
# Bio:  47
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GRAEFF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  ( Gerrit de ) ( 1 ) , zoon van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Johan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  ( kol . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">501 ) , 23 Febr . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1711 - 10 Nov . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1752 , promoveerde 27 Juni 1732 te Leiden in de rechten . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij verkreeg na het overlijden van zijn moeder in 1738 de heerlijkheid van Zuid Polsbroek en volgde zijn oom Cornelis op als heer van Purmerland en Ilpendam in 1722 . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij was commissaris van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100en
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  en andere penningen 1736-38 en 1740-52 van den grooten accijns ; in 1736 bewindhebber van de W.-I. Compagnie en werd in 1739 tot Schepen gekozen . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Jacob Bicker Raye geeft over hem in zijn aanteekeningen te lezen : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">‘ Hij laat een schat van gelt naar , dog was uytermaate suynig , beknibbelde ider ter alder scharpste , gunde een ander niets , benijdende een iders welvaart , en hat plisier om die geene , daar hij over gestelt was , haar inkomen en emolumente te besnoyje , bedisputeeren en te verminderen , sodat hij , na gedachte , van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weinige
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , als hij niemandt
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     goet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     deet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  ( als zeer gedwongen ) betreurt sal worden ’ . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij was eerst gehuwd met Maria Elisabeth Sautijn in
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1734
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">hertrouwde twee jaren later met Elizabeth Lestevenon , uit welk huwelijk hem twee dochters overleefden en een zoon , die volgt . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zie : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Literatuur bij Pieter de Graeff ( kol . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">502 vlg. ) . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Veder </div></span>
# Bio:  48
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOOT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  ( Jonkheer
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     van
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  ) </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">noemde zich ‘ Patricius van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Antwerpen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , ’ en schreef op elk der XVI boeken van Pegasides Pleyn van zijn tijdgenoot Houwaert , een sonnet . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij overtrof hem niet in poëzy , maar gebruikte minder bastaardwoorden . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zijne zinspreuk was : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Tempera te tempori ( Schik u naar den tijd ) . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij overleed te Antwerpen in
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1590
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij schreef in het Ned. en Fransch : Cort begryp der XII boucken Olympiados , in 't Vl . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">en Fr. , Antw . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Giles van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , 1579 , kl . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">fol . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">met portret van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schrijver
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , in 't koper . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hymne de Braband , Anvers , 1580 , fol . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     avec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fig.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">De poëtische Wercken van mijn Heere van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     der
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Noot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , 1581 , 1593 , 1594 , fol . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">met portret ( in houtsnede ) en platen . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Willems bezat een exemplaar , waarbij gevoegd was eene copie van verschillende stukken , getrokken uit de archiven van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Antwerpen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , rakende van der Noot's poorterschap , verkregen 2 Junij 1558 , zijn huwelijk te Leuven en onderstand in geld voor het in druk geven zijner werken . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Diverses Oeuvres poëtiques , Anvers , 1581 , 1 vol. kl . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">fol .    </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zie Willems , Verh . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">over de Ned. Taal- en Lett. D. I. bl. 290 ; Antw . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Alm . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1820 . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">bl.
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     53
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Witsen Geysbeek ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin
# Bio:  49
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Portret van de geestelijke Hendrik van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alckemade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div></span>
