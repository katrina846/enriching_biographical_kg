# %% [markdown]
# # Experiment 3

# %% [markdown]
# This notebook contains the code for experiment 3.

# %% [markdown]
# ## Loading libraries/packages and the training and test data

# %%
import ssl
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

import numpy as np
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
ssl._create_default_https_context = ssl._create_unverified_context
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag import pos_tag
from itertools import chain

import nltk
import sklearn 
import re 
import scipy.stats
import spacy_dbpedia_spotlight

# %%
# %store -r test_data

# %%
train_sents = list(nltk.corpus.conll2002.iob_sents('ned.train'))

# %% [markdown]
# ## Feature engineering (credits: https://github.com/TeamHG-Memex/sklearn-crfsuite/blob/master/docs/CoNLL2002.ipynb)

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'word': word,
        'word.isLower': word.lower(),
        'word.isUpper': word.isupper(),
        'word.isTitle': word.istitle(),
        'word.endsWithPeriod': word.endswith("."),
        'word.isAbbreviation': bool(re.match(r"^((?i)([A-Z])\.)+$", word)),
        'word.containsHyphen': word.find("-"), 
        'word.containsApostrophe': word.find("'"), 
        
    }
    if i > 0:
        prev = sent[i-1][0]
        features.update({
            '-1:word': prev,
            '-1:word.isLower': prev.lower(),
            '-1:word.isUpper': prev.isupper(),
            '-1:word.isTitle': prev.istitle(),
            '-1:word.endsWithPeriod': prev.endswith("."),
            '-1:word.isAbbreviation': bool(re.match(r"^((?i)([A-Z])\.)+$", prev)),
            '-1:word.containsHyphen': prev.find("-"), 
            '-1:word.containsApostrophe': prev.find("'")
        })
    
    if i > 1:
        prev = sent[i-2][0]
        features.update({
            '-2:word': prev,
            '-2:word.isLower': prev.lower(),
            '-2:word.isUpper': prev.isupper(),
            '-2:word.isTitle': prev.istitle(),
            '-2:word.endsWithPeriod': prev.endswith("."), 
            '-2:word.isAbbreviation': bool(re.match(r"^((?i)([A-Z])\.)+$",  prev)),
            '-2:word.containsHyphen': prev.find("-"),
            '-2:word.containsApostrophe': prev.find("'")
        })
    
        
    if i < len(sent)-1:
        next_token = sent[i+1][0]
       
        features.update({
            '+1:word': next_token,
            '+1:word.isLower': next_token.lower(),
            '+1:word.isUpper': next_token.isupper(),
            '+1:word.isTitle': next_token.istitle(),
            '+1:word.endsWithPeriod': next_token.endswith("."), 
            '+1:word.isAbbreviation': bool(re.match(r"^((?i)([A-Z])\.)+$", next_token)),
            '+1:word.containsHyphen': next_token.find("-"),
            '+1:word.containsApostrophe': next_token.find("'")
        })
        
   
    if i < len(sent)-2:
        next_token = sent[i+2][0]
       
        features.update({
            '+2:word': next_token,
            '+2:word.isLower': next_token.lower(),
            '+2:word.isUpper': next_token.isupper(),
            '+2:word.isTitle': next_token.istitle(),
            '+2:word.endsWithPeriod': next_token.endswith("."), 
            '+2:word.isAbbreviation': bool(re.match(r"^((?i)([A-Z])\.)+$", next_token)),
            '+2:word.containsHyphen': next_token.find("-"),
            '+2:word.containsApostrophe': next_token.find("'")
    })

                
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %% [markdown]
# ### Training

# %%
training_features = [sent2features(s) for s in train_sents]
training_labels = [sent2labels(s) for s in train_sents]
# Out:
# C:\Users\katri\AppData\Local\Temp\ipykernel_37292\3855163242.py:11: DeprecationWarning: Flags not at the start of the expression '^((?i)([A-Z])\\.)+$' but at position 2
#   'word.hasabbrev': bool(re.match(r"^((?i)([A-Z])\.)+$", word)),

# %%
import sklearn_crfsuite
from sklearn_crfsuite import CRF
from sklearn.metrics import classification_report

crf = CRF(algorithm='l2sgd',
          max_iterations=100,
          all_possible_transitions=False)

# %%
crf.fit(training_features, training_labels)
# Out:
# CRF(algorithm='l2sgd', all_possible_transitions=False, max_iterations=100)

# %% [markdown]
# ### Feature extraction for test data

# %%
test_inputs = []
for snippet in test_data:
    sent_features = [sent2features(s) for s in snippet]
    test_inputs.append(sent_features)

# %% [markdown]
# ## Model predictions

# %%
from sklearn.metrics import classification_report
pred_outputs = []
for biography in test_inputs:
    pred = crf.predict(biography)
    pred_outputs.append(pred)

# %% [markdown]
# ## Formatting predictions

# %%
list_of_pred = [] 
for snippet in pred_outputs:
    for sent in snippet:
        for token in sent:
            list_of_pred.append(token)

# %%
pred_test_set = test_data
for snippet_index in range(len(pred_test_set)):
    snippet = pred_test_set[snippet_index]
    for sent_index in range(len(snippet)):
        sent = snippet[sent_index]
        pred_test_set[snippet_index][sent_index]= [list(ele) for ele in sent]
    
print(pred_test_set[0][0])
# Out:
# [['MATHAM', 'NNP'], ['(', '('], ['Theodorus', 'NNP'], [')', ')'], [',', ','], ['zoon', 'FW'], ['van', 'FW'], ['Jacobus', 'NNP'], ['Matham', 'NNP'], [',', ','], ['werd', 'NN'], ['in', 'IN'], ['1598', 'CD'], ['te', 'NN'], ['Haarlem', 'NNP'], ['geboren', 'NN'], [',', ','], ['bezocht', 'NN'], ['Italië', 'NNP'], [',', ','], ['en', 'FW'], ['arbeidde', 'FW'], ['aldaar', 'FW'], ['met', 'FW'], ['Cornelis', 'NNP'], ['Blommaent', 'NNP'], [',', ','], ['Natalis', 'NNP'], ['Persyn', 'NNP'], ['en', 'FW'], ['andere', 'RB'], ['Vlaamsche', 'NNP'], ['schilders', 'NNS'], ['aan', 'VBP'], ['de', 'IN'], ['Standbeelden', 'NNP'], ['enz.', 'NN'], ['in', 'IN'], ['de', 'FW'], ['galerij', 'FW'], ['van', 'FW'], ['het', 'NN'], ['paleis', 'NN'], ['Ginstiniani', 'NNP'], ['.', '.']]

# %%
k = 0 
i = 0
for snippet_i in range(len(pred_test_set)):
    snippet = pred_test_set[snippet_i]
    for sent_i in range(len(snippet)):
        sent= pred_test_set[snippet_i][sent_i]
        for token_i in range(len(sent)):
            pred_ner = list_of_pred[k]
            pred_test_set[snippet_i][sent_i][token_i].append(pred_ner)
            k+=1
            i += 1

# %% [markdown]
# ## Visualizing predicted results

# %%
def visualize_biography(text):
    import spacy
    from spacy.tokens import Doc, Span
    from spacy import displacy

    nlp = spacy.load("en_core_web_sm")

    vocab = nlp.vocab
    colors = {"B-PER": "#ADD8E6","I-PER": "#ADD8E6", "B-LOC": "#FFD580", "I-LOC": "#FFD580", "B-ORG":"#90EE90","I-ORG":"#90EE90", "B-MISC":"#D8BFD8","I-MISC":"#D8BFD8"}

    docs = []
    for sentence in text:
        without_pos = [[a, c] for [a, b, c] in sentence]
        words, entities = zip(*without_pos)
        doc = Doc(vocab, words=words)
        spans = [Span(doc, i, i + 1, label=ent_type) for i, ent_type in enumerate(entities) if ent_type]
        doc.ents = spans
        docs.append(doc)

    options = {"ents": ["B-PER", "I-PER","B-ORG","I-ORG", "B-LOC","I-LOC","B-MISC","I-MISC"], "colors": colors}
    displacy.render(docs, style="ent", options=options, jupyter=True)

# %%
def count_tag(tag,test_set): 
    count = 0 
    for bio in test_set:
        for sentence in bio: 
            for token in sentence:
                if token[2] == tag:
                    count += 1
                    
    return count

# %%
print('B-PER', count_tag('B-PER',pred_test_set))
print('I-PER',count_tag('I-PER',pred_test_set))
print('B-LOC',count_tag('B-LOC',pred_test_set))
print('I-LOC',count_tag('I-LOC',pred_test_set))
print('B-ORG',count_tag('B-ORG',pred_test_set))
print('I-ORG',count_tag('I-ORG',pred_test_set))
print('B-MISC',count_tag('B-MISC',pred_test_set))
print('I-MISC',count_tag('I-MISC',pred_test_set))
# Out:
# B-PER 670
# I-PER 638
# B-LOC 528
# I-LOC 73
# B-ORG 131
# I-ORG 82
# B-MISC 388
# I-MISC 137

# %%
i=0
for bio in pred_test_set:
    print("Bio: ",i)
    visualize_biography(bio)
    i+=1
# Out:
# Bio:  0
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MATHAM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Theodorus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ) , zoon van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jacobus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , werd in 1598 te Haarlem geboren , bezocht
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Italië
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , en arbeidde aldaar met
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cornelis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blommaent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  ,
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Natalis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Persyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  en andere Vlaamsche schilders aan de Standbeelden enz. in de galerij van het paleis
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ginstiniani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij vestigde zich vervolgens te 's Hage , waar hij een der medeoprigters van de kamer Pictura was . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij sneed vele voortreffelijke portretten naar de beroemde meesters , die door
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nagler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  en
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kramm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  worden vermeld . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zoo als dat van
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michiel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     le
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-MISC</span>
# </mark>
#
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-MISC</span>
# </mark>
#  , agent van de koningin en de kroon van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zweden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  bij
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Z.M.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  den koning van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Groot-Brittanje
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  in fol . ; </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">naar van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dyck
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ;
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Philip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rovenius
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , pauselijk vicaris in
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     België
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , naar
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rubens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , in
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# Bio:  1
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Adel , aquarellist , schilder . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Geboren : 30 maart 1880 ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venlo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Gestorven : 4 februari 1951 ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haag
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Plaats en periode van werkzaamheid : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haag
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  , van 1895 tot 1951 Ca. van vóór 1895-1951 . </div></span>
# Bio:  2
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HOUTEN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#  ( Mr.
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bernardus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Albertus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">van ) , studeerde te Leyden , werd 5 Oct . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1793 mr. in de regten . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">na het verdedigen eener Diss. jur. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">de
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Judicibus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hollandis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">certa
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     privatas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">judicandi </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">causas </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">norma nusquam distitutis cet . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij vestigde zich te Amsterdam en
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     stierf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij schreef : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Verhandeling over den pligt der regters in
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Holland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  en West-Vriesland om alleen naar den inhoud der wetten vonnis te vellen ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amst
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1794 , gr. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">8o . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Regtsgeleerd advys in de zaak van mr.
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     R.W.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tadama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  tegen
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     H.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  en
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     H.M.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Levy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amst
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1801 , gr. 8o . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Proces tegen
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     H.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jansen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  wegens doodslag , met aanmerkingen ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amst
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1803 , gr. 8o . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">De
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nederlandsche
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  burgerlijke wetgeving ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amst
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC<
# Bio:  3
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ENGELMAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Martinus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gerardus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-MISC</span>
# </mark>
#  ) , geb. te
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amsterdam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1772 ( ? ) , ‘ ambtenaar ’ aldaar , en er overleden 13 Febr . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1823 ; vertaler , deels bewerker , van een aantal tooneelstukken uit het
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fransch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  en
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hoogduitsch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , schrijver van een paar gelegenheidsgedichten . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">'s Mans voorreden geven een enkelen keer aan , welke wijzigingen hij bij de vertaling bracht
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">levensbijzonderheden zijn er niet uit te putten . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">De volgende geschriften zijn van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     E.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  bekend : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">ze zijn alle te Amsterdam verschenen en dragen , waar het tegendeel niet vermeld is , den naam van den auteur op het titelblad
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Het magnetismus . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Blijspel naar
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iffland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ( 1798 )
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">De dragonders en de
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benedictijner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  nonnen . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Blijspel naar
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pigaultle-Brun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ( 1799 )
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">De tooveres Sidonia , tooneelspel naar
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     H.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zschokke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  ( 1799 ; 2 . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">druk 1801 ) ; Middernacht . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Blijspel naar
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Desaudras
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ( 1800 )
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Roland de
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monglave
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , of de zegepraal der onschuld . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Tooneelspel naar
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Loaisel-Téogate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# <
# Bio:  4
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEPP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cornelis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ) , 20
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sept
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1810 te Amsterdam geb. en overl . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">ald . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">31
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1868 , was de laatste uit een aanzienlijke boekhandelaarsfamilie , sedert de 18de eeuw in deze stad gevestigd . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zij was toen uit
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Goslar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  herwaarts gekomen . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zijn vader ,
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sepp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , overl . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1853 , en ook zijn grootvader ,
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christiaan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , gest. 1811 , maakten zich vooral naam op 't gebied der vogel- en insectenkunde . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cornelis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  zette de kostbare uitgaven van zijn vader en grootvader voort , hierin bijgestaan door
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S.C.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Snellen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vollenhoven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  e.a. Behalve een beroemd werk over de entomologie ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nederl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">insecten getiteld , gaf hij ook een uitgebreide
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Flora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Batava
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-MISC</span>
# </mark>
#  in het licht . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Maar met zijn dood hield de uitgeversfirma
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     J.C.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seppen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  Zoon op te bestaan . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">De fondsartikelen werden verkocht
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">een belangrijke verzameling entomologische teekeningen werden
# Bio:  5
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Fotograaf . </div></span>
# Bio:  6
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Portret van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Caspar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Janszoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coolhaes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
#  Portret van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Caspar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Janszoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coolhaes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , theoloog en hervormd predikant . </div></span>
# Bio:  7
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ASSELIERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Johannes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ) , een Antwerpenaar van geboorte , werd na zijne studie volbragt te hebben , tot Doctor in de beide
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  bevorderd en tot Secretaris van zijne geboortestad aangesteld . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In zijne jeugd deed hij reizen door
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Italië
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankrijk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Duitschland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  en de voornaamste landen van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , waar hij eeae groote voorraad van kunde en geleerdheid opdeed . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In den opstand tegen
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanje
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  hield bij de zijde der Staten , en werd in
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  1577 tot
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seeretaris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     van
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Staatsraad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  onder den
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aartshertog
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matthias
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  benoemd . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij zocht in 1579 die van 's Hertogenbosch te bewegen om vijf of zes vaandelen Schotten in te nemen , ten einde zich tegen de
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanjaarden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  te kunnen verdedigen . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Ook was hij een goed
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Staatsman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  en werd benevens
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Moulliere
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-MISC</span>
# </mark>
#  in 1584 door de
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algemeene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Staten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  als Gezant naar
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankrijk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  gezonden , ten einde
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Koning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">
# Bio:  8
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MENSE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Willem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  ) , bouwman te Klundert , lidmaat en diaken der Hervormde gemeente , geraakte in geschil met
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Philippus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     van
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dueren
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , predikant in de
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fynaart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , waarop hij door den kerkeraad van de
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Klundert
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  onder censure werd gesteld . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zie : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Waaragtig verhaal van het voorgevallene tusschen Philippus van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dueren
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , predikant in den
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fynaart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  en
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Willem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mense
# ...
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1711 - 10
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nov
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">1752 , promoveerde 27 Juni 1732 te Leiden in de rechten . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij verkreeg na het overlijden van zijn moeder in 1738 de heerlijkheid van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zuid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Polsbroek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  en volgde zijn oom Cornelis op als heer van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purmerland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  en
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ilpendam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  in 1722 . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij was commissaris van den 100en en andere penningen 1736-38 en 1740-52 van den grooten accijns ; in 1736 bewindhebber van de
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     W.-I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Compagnie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  en werd in 1739 tot Schepen gekozen . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jacob
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bicker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raye
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  geeft over hem in zijn aanteekeningen te lezen : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">‘ Hij laat een schat van gelt naar , dog was uytermaate suynig , beknibbelde ider ter alder scharpste , gunde een ander niets , benijdende een iders welvaart , en hat plisier om die geene , daar hij over gestelt was , haar inkomen en emolumente te besnoyje , bedisputeeren en te verminderen , sodat hij , na gedachte , van seer weinige , als hij niemandt goet deet ( als zeer gedwongen ) betreurt sal worden ’ . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij was eerst gehuwd met
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elisabeth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sautijn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  in 1734
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">hertrouwde twee jaren later met
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elizabeth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lestevenon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , uit welk huwelijk hem twee dochters overleefden en een zoon , die volgt . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zie : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Literatuur bij
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pieter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity
# Bio:  48
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOOT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#  ( Jonkheer
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     van
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  ) </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">noemde zich ‘ Patricius van
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Antwerpen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , ’ en schreef op elk der XVI boeken van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pegasides
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pleyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  van zijn tijdgenoot
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Houwaert
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#  , een sonnet . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij overtrof hem niet in poëzy , maar gebruikte minder bastaardwoorden . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Zijne zinspreuk was : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Tempera te tempori ( Schik u naar den tijd ) . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij overleed te
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Antwerpen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  in 1590 . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hij schreef in het Ned. en Fransch : Cort begryp der
# <mark class="entity" style="background: #90EE90; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XII
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#  boucken Olympiados , in 't
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">en Fr. ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Antw
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Giles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     van
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , 1579 , kl . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">fol . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">met portret van
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     den
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schrijver
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  , in 't koper . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Hymne de
# <mark class="entity" style="background: #D8BFD8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Braband
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-MISC</span>
# </mark>
#  ,
# <mark class="entity" style="background: #FFD580; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anvers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOC</span>
# </mark>
#  , 1580 , fol . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">avec fig. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">De poëtische Wercken van mijn
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Heere
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     van
# Bio:  49
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Portret van de geestelijke
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hendrik
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     van
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#
# <mark class="entity" style="background: #ADD8E6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alckemade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  </div></span>
